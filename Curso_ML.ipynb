# %% [markdown]
# <a href="https://colab.research.google.com/github/mcozono/Cursos/blob/master/Curso_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#libs

import pandas as pd
import numpy as np


#libs gráficas

# %% [markdown]
# #**Pergunta de negócio a ser respondida**

# %%
#carregando a base de dados
Base_dados = pd.read_csv('/content/drive/MyDrive/42 - ML Classes/house_data.csv')

# %%
#recuperação de linhas e colunas - dimensao
Base_dados.shape
# Out:
# (10692, 13)

# %%
#cabeçalho e nome das colunas do dataset e as primeiras linhas
Base_dados.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# ...

# %%
#removendo colunas

Base_dados.drop(columns=['fire insurance (R$)','total (R$)'], inplace= True) #informando a lista com os títulos a serem dropados

# %%
#dataset sem colunas
Base_dados.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
